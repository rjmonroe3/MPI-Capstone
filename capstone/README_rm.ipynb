# %% [markdown]
# # Capstone Summary

# %% [markdown]
# #### Purpose
#
# My capstone project takes the Multidimensional Poverty Index data and answers the following questions:
# - Which regions in the world have the highest poverty rate according to MPI?
# - Which regions in the world have the highest intensity of depravation according to MPI?
# - Is there a correlation between a region and their MPI?

# %% [markdown]
# The first step I take is doing exploratory data analysis. From this analysis I found that I would be working with a small dataset. Futhermore, I was able to answer the first two questions from my analysis. I think this was possible to do in the analysis becasue the data was small or the questions were not complicated.
#
# ##### Finding the highest poverty rate according to MPI
# Once my data was loaded, I did the following to find my answer:
# 1. Grouped the data by world region
# 2. Calculated the mean for each column
# 3. Sorted the data by the MPI
#
# From this I concluded that Sub-Sahara Africa has the highest MPI
# ![MPI%20Regional.JPG](attachment:MPI%20Regional.JPG)

# %% [markdown]
# ##### Which regions have the highest inensity of deprivation
#
# To find which region of the world has the highesty intensity of deprivation, I followed the same steps as before and found out that Sub-Sahara Africa and South Asia has the highest deprivation.
#
# ![Intensity%20of%20Dep.JPG](attachment:Intensity%20of%20Dep.JPG)

# %% [markdown]
# #### Creating Linear Regression Models
#
# To answer the last question regarding relationships exsisting between a region and their MPI, I created a linear regression model. Before I create the model, I realized another variable called 'headcount ratio', which I could use to help understand possible relationships.
#
# After plotting and running a regression line I could see that as the deprivation increases so too did the MPI.
# ![MPI%20v%20Intensity.JPG](attachment:MPI%20v%20Intensity.JPG)
#
# From there I split my data and trained it in order to predict a regions MPI based on intensity. The predictions seemed to be accurate, but to be sure I calcualed the mean square error and root mean square error.

# %% [markdown]
# ![Train%20and%20Test%20on%201V.JPG](attachment:Train%20and%20Test%20on%201V.JPG)

# %% [markdown]
# Running the predicted regression line
# ![MPI%20v%20Intensity%20with%20Predictions.JPG](attachment:MPI%20v%20Intensity%20with%20Predictions.JPG)

# %% [markdown]
# After seeing the results with just one varible, I decided to run the model using two varibles; this time included the the headcout ratio.
#
# After the following the same steps as before, my modle was even more accurate predicting a regions MPI based on the intensity and headcout ratio.
#
# ![Train%20and%20Test%20on%202V.JPG](attachment:Train%20and%20Test%20on%202V.JPG)

# %% [markdown]
# #### Creating K-Means Clustering Models

# %% [markdown]
# I wanted to try one more model to see if it would be a better indicator at predicting a regions relationship with their MPI. So, I decided to go with a clustering model to find similarities within the dataset and group them together.

# %% [markdown]
# For the first K-Means clustering model I decided to build the model using 3 clusters with 1 random point. My observation of the model was clear distinct grouping, but it seemed like there was some overlap.
# ![Clustering%20MPI%203.JPG](attachment:Clustering%20MPI%203.JPG)

# %% [markdown]
# I wanted to see if adding another cluster would give more accucary to the model, just like adding another variable gave accuracy to the liner regression model.
#
# ![MPI%20Cluster%203.JPG](attachment:MPI%20Cluster%203.JPG)

# %% [markdown]
# After adding another cluster I can see the model trying to create distinct groupsing at every tenth step(i.e., 0.0-0.1, 0.1-0.2, etc..). There was more definitive lines, but clear overlaping as well.

# %% [markdown]
# ### Conclusion
#
# My conclusion for predicting a country's deprivation based on it's MPI is that there is a strong relationship between both variables. Some overlap occurs, but the strong model in my opinoin to use would be the K-Means Clustering model. I think with more clustering points the lines will become more distinct and the model will be able to predict the intensity of deprevation of a region based on it's MPI.
